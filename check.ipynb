# %%
def amazonScraper():
    try:
        import requests
        from bs4 import BeautifulSoup
        for pg in range(1,6):
            for _ in range(1,20):
                url = f"https://www.amazon.in/s?k=plants&qid=1700117564&ref=sr_pg_{pg}"
                headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}
                req = requests.get(url,headers=headers)
                if req.status_code == 200:
                    print(url)
                    print(req)
                    soup = BeautifulSoup(req.content,"html.parser")
                    for i in soup.find_all("span",{"class":"a-size-base-plus a-color-base a-text-normal"}):
                        print(i.text.strip())
                    break
            else:
                print(url)
                print("timedOut..!")
                

    except Exception as e:
        print(e)
amazonScraper()
# Out:
# https://www.amazon.in/s?k=plants&qid=1700117564&ref=sr_pg_1
# <Response [200]>
# Ugaoo Lucky Bamboo 3 Layer Feng Shui Plant
# Ugaoo Indoor Plants Combo of 4 - Money Plant Variegated, Philodendron Brasil, Fittonia, Broken Heart Live Plant for Home Decor
# MorningVale Areca Palm tree live plant best indoor air purifying plant include pot
# Ugaoo Good Luck Jade Plant with Self Watering Pot
# Guruji Plantation Real Live Hybrid Sarbati Lemon Nimbu Lime Citrus Tree Bush Cultivar Variety Species Citron Limon Fruit Bearing Plant for Garden with Plastic Pot
# Hari Giver Garden® Pink Peace Lily, Spathiphyllum Indoor Air Purify Plant 1 Healthy Live Plant With Mini Black Pot
# Kraft Seeds Rajnigandha Double Flowering Bulbs (White, 22 Bulbs) | Fragrant Flower Bulbs for Pots | Flower Plants Bulbs for Indoor Home Decor | Night Bloom Flowering Bulbs for Home Garden
# Ugaoo Philodendron Broken Heart Indoor Plant With Self Watering Pot - Monstera Adansonii
# ...

# %%
import scraper_helper as healper

# %%
data = """
Accept:
text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7
Accept-Encoding:
gzip, deflate, br
Accept-Language:
en-US,en;q=0.9
Cache-Control:
max-age=0
Cookie:
session-id=258-0474392-6562854; i18n-prefs=INR; ubid-acbin=259-9556480-6955548; session-id-time=2082787201l; lc-acbin=en_IN; mbox=PC#38a6e0aab875484b85e5dee35a36f1ff.41_0#1763281185|session#a62eef61b8154dd893830a6da44c2df1#1700038245; AMCV_5E35755F5B7C1B910A495C46%40AdobeOrg=179643557%7CMCIDTS%7C19677%7CMCMID%7C20808944824496761743885969780604731997%7CMCAAMLH-1700641183%7C12%7CMCAAMB-1700641183%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-1700043583s%7CNONE%7CMCSYNCSOP%7C411-19684%7CvVersion%7C5.5.0%7CMCCIDH%7C1847503529; adcloud={%22_les_v%22:%22y%2Camazon.in%2C1700038184%22}; session-token=; csm-hit=adb:adblk_no&t:1700124219176&tb:s-DCKEX84CSGH3XBMHVK15|1700124218734
Device-Memory:
8
Downlink:
10
Dpr:
0.75
Ect:
4g
Rtt:
100
Sec-Ch-Device-Memory:
8
Sec-Ch-Dpr:
0.75
Sec-Ch-Ua:
"Microsoft Edge";v="119", "Chromium";v="119", "Not?A_Brand";v="24"
Sec-Ch-Ua-Mobile:
?0
Sec-Ch-Ua-Platform:
"Windows"
Sec-Ch-Ua-Platform-Version:
"15.0.0"
Sec-Ch-Viewport-Width:
937
Sec-Fetch-Dest:
document
Sec-Fetch-Mode:
navigate
Sec-Fetch-Site:
none
Sec-Fetch-User:
?1
Upgrade-Insecure-Requests:
1
User-Agent:
Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0
"""



healper.get_dict(data)
# Out:
# {}

# %%
# %%writefile scrapeAmazon.py
def amazonScraper():
    try:
        import requests
        from bs4 import BeautifulSoup
        for pg in range(1,6):
            for _ in range(1,20):
                url = f"https://www.amazon.in/s?k=plants&qid=1700117564&ref=sr_pg_{pg}"
                headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}
                req = requests.get(url,headers=headers)
                if req.status_code == 200:
                    print(url)
                    print(req)
                    soup = BeautifulSoup(req.content,"html.parser")
                    for i in soup.find_all("span",{"class":"a-size-base-plus a-color-base a-text-normal"}):
                        print(i.text.strip())
                    break
            else:
                print(url)
                print("timedOut..!")
                

    except Exception as e:
        print(e)
amazonScraper()
# Out:
# Writing scrapeAmazon.py

# %%
import re
from playwright.sync_api import Page, expect

def test_has_title(page: Page):
    page.goto("https://playwright.dev/")

    # Expect a title "to contain" a substring.
    expect(page).to_have_title(re.compile("Playwright"))

def test_get_started_link(page: Page):
    page.goto("https://playwright.dev/")

    # Click the get started link.
    page.get_by_role("link", name="Get started").click()

    # Expects page to have a heading with the name of Installation.
    expect(page.get_by_role("heading", name="Installation")).to_be_visible()

# %%
pip install playwright
# Out:
# ...
#   Using cached pyee-9.0.4-py2.py3-none-any.whl (14 kB)
# ...
#   Attempting uninstall: pyee
#     Found existing installation: pyee 8.2.2
#     Uninstalling pyee-8.2.2:
#       Successfully uninstalled pyee-8.2.2
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyppeteer 1.0.2 requires pyee<9.0.0,>=8.1.0, but you have pyee 9.0.4 which is incompatible.
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
playwright install
# Out:
#   Cell In[42], line 1
#     playwright install
#                ^
# SyntaxError: invalid syntax

# %%
pip install pytest-playwright
# Out:
# ...
#                                               0.0/325.1 kB ? eta -:--:--
#      --------                                71.7/325.1 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 325.1/325.1 kB 4.0 MB/s eta 0:00:00
# ...
#                                               0.0/78.2 kB ? eta -:--:--
#      ---------------------------------------- 78.2/78.2 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pytest
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\plants_scrapy\check.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/plants_scrapy/check.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> pytest
#
# NameError: name 'pytest' is not defined
